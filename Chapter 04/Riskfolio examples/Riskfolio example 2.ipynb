# %% [markdown]
# # Riskfolio-Lib Tutorial:
# <br>__[Financionerioncios](https://financioneroncios.wordpress.com)__
# <br>__[Orenji](https://www.orenj-i.com)__
# <br>__[Riskfolio-Lib](https://riskfolio-lib.readthedocs.io/en/latest/)__
# <br>__[Dany Cajas](https://www.linkedin.com/in/dany-cajas/)__
# ## Part II: Portfolio Optimization with Risk Factors using Stepwise Regression
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Tickers of factors

factors = ['MTUM', 'QUAL', 'VLUE', 'SIZE', 'USMV']
factors.sort()

tickers = assets + factors
tickers.sort()

# Downloading data
data = yf.download(tickers, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = tickers
# Out:
# [*********************100%***********************]  29 of 29 completed

# %%
# Calculating returns

X = data[factors].pct_change().dropna()
Y = data[assets].pct_change().dropna()

display(X.head())
# Out:
#                MTUM     QUAL     SIZE     USMV     VLUE
# Date
# 2016-01-05  0.4735%  0.2672%  0.0000%  0.6780%  0.1635%
# 2016-01-06 -0.5267% -1.1914% -0.5380% -0.6253% -1.8277%
# 2016-01-07 -2.2293% -2.3798% -1.7181% -1.6215% -2.1609%
# 2016-01-08 -0.9548% -1.1376% -1.1978% -1.0086% -1.0873%
# 2016-01-11  0.6043%  0.1480% -0.5898%  0.1491% -0.6183%

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Estimating the loadings matrix.
#
# This part is just to visualize how Riskfolio-Lib calculates a loadings matrix.

# %%
import riskfolio.ParamsEstimation as pe

step = 'Forward' # Could be Forward or Backward stepwise regression
loadings = pe.loadings_matrix(X=X, Y=Y, stepwise=step)

loadings.style.format("{:.4f}").background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow0_col0,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow0_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow5_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow15_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow18_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow22_col3{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow0_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow1_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow6_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow7_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow8_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow9_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow11_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow13_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow18_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow19_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow20_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow23_col2{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow0_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow0_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow7_col0,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow14_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow16_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow17_col2{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow0_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow13_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow15_col0{
#             background-color:  #dc3b2c;
#             color:  #f1f1f1;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow1_col0{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow1_col1{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow1_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow2_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow3_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow4_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow4_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow5_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow7_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow8_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow10_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow12_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow13_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow15_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow16_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow18_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow20_col3{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow1_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow17_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow20_col5{
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow1_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow2_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow3_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow4_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow5_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow12_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow13_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow14_col5{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow2_col0{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow2_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow3_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow6_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow8_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow9_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow10_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow11_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow15_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow20_col1,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow21_col1{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow2_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow15_col5{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow2_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow6_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow8_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow9_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow11_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow20_col4{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow3_col0,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow11_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow3_col2,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow7_col1{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow3_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow22_col0{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow4_col0{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow4_col1{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow4_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow10_col0{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow5_col0{
#             background-color:  #f57547;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow5_col1{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow5_col4{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow6_col0{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow6_col3,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow23_col3{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow6_col5{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow7_col4{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow7_col5{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow8_col0{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow8_col5,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow12_col2{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow9_col0,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow12_col4{
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow9_col3{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow9_col5{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow10_col2{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow10_col4,#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow21_col0{
#             background-color:  #ef633f;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow10_col5{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_5eac29dc_3b06_11eb_b3f2_f8b46ac0975drow11_col0{
#             backgr

# %% [markdown]
# ### 2.2 Calculating the portfolio that maximizes Sharpe ratio.

# %%
port.assets_stats?

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)

# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

port.factors = X
port.factors_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='FM' # Factor Model
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = False # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA      BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 10.7366% 0.0000% 0.0000% 8.8164% 0.0000% 4.4015% 11.9282%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 14.9636% 0.0000% 8.9182% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 5.4728% 0.0000% 3.3483% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 2.3 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe FM Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       APA      BAX     BMY   CMCSA      CNP     CPB      DE     DHR     HPQ  \
# 0 0.0000%  2.1991% 4.5591% 3.8256%  9.2597% 5.3360% 0.0000% 0.7115% 0.0000%
# 1 0.0000%  7.1031% 0.0259% 3.1105% 11.3751% 2.6165% 1.1440% 4.7942% 0.0000%
# 2 0.0000%  8.3819% 0.0000% 2.1778% 11.9097% 1.2467% 1.9380% 6.3285% 0.0000%
# 3 0.0000%  9.3622% 0.0000% 0.6565% 11.5806% 0.0000% 2.7450% 7.9841% 0.0000%
# 4 0.0000% 10.0224% 0.0000% 0.0000% 10.3914% 0.0000% 3.5657% 9.7505% 0.0000%
#
#       JCI  ...     MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 4.7328%  ...  0.0000% 0.0000% 12.8295% 0.0000% 13.7885% 1.3273% 4.3013%
# 1 2.1134%  ...  1.5983% 0.0000% 14.3571% 0.0000%  5.7155% 0.0000% 5.2877%
# 2 0.4634%  ...  4.4822% 0.0000% 14.6208% 0.0000%  1.6405% 0.0000% 5.5047%
# 3 0.0000%  ...  7.6429% 0.0000% 13.6883% 0.0000%  0.0000% 0.0000% 5.6022%
# 4 0.0000%  ... 10.9956% 0.0000% 11.5575% 0.0000%  0.0000% 0.0000% 5.5867%
#
#       TXT       VZ    ZION
# 0 0.0000% 11.3439% 2.2330%
# 1 0.0000% 11.1573% 2.0792%
# 2 0.0000% 10.6892% 1.5642%
# 3 0.0000%  9.1817% 0.8961%
# 4 0.0000%  6.6387% 0.1013%
#
# [5 rows x 24 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu_fm # Expected returns
cov = port.cov_fm # Covariance matrix
returns = port.returns_fm # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:319: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["{:.4%}".format(x) for x in ax.get_yticks()])
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:320: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["{:.4%}".format(x) for x in ax.get_xticks()])

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:558: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["{:3.2%}".format(x) for x in ax.get_yticks()])

# %% [markdown]
# ## 3. Optimization with Constraints on Risk Factors

# %% [markdown]
# ### 3.1 Statistics of Risk Factors

# %%
# Displaying factors statistics

display(loadings.min())
display(loadings.max())
display(X.corr())
# Out:
# const     -0.0588%
# MTUM     -65.6600%
# QUAL     -59.9244%
# SIZE     -28.9644%
# USMV    -120.9410%
# VLUE     -49.1498%
# dtype: float64
# const     0.0689%
# MTUM    103.0863%
# QUAL    102.9863%
# SIZE     93.8026%
# USMV    232.5675%
# VLUE    172.7817%
# dtype: float64
#           MTUM      QUAL      SIZE      USMV      VLUE
# MTUM 100.0000%  90.4264%  79.1707%  87.2320%  78.5393%
# QUAL  90.4264% 100.0000%  89.8148%  89.9553%  91.6579%
# SIZE  79.1707%  89.8148% 100.0000%  82.5555%  87.8455%
# USMV  87.2320%  89.9553%  82.5555% 100.0000%  76.9677%
# VLUE  78.5393%  91.6579%  87.8455%  76.9677% 100.0000%

# %% [markdown]
# ### 3.2 Creating Constraints on Risk Factors

# %%
# Creating risk factors constraints

import riskfolio.ConstraintsFunctions as cf

constraints = {'Disabled': [False, False, False, False, False],
               'Factor': ['MTUM', 'QUAL', 'SIZE', 'USMV', 'VLUE'],
               'Sign': ['<=', '<=', '<=', '>=', '<='],
               'Value': [-0.3, 0.8, 0.4, 0.8 , 0.9],}

constraints = pd.DataFrame(constraints)

display(constraints)
# Out:
#    Disabled Factor Sign     Value
# 0     False   MTUM   <= -30.0000%
# 1     False   QUAL   <=  80.0000%
# 2     False   SIZE   <=  40.0000%
# 3     False   USMV   >=  80.0000%
# 4     False   VLUE   <=  90.0000%

# %%
C, D = cf.factors_constraints(constraints, loadings)

# %%
port.ainequality = C
port.binequality = D

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA      CNP     CPB      DE     DHR  \
# weights 0.0000% 0.0000% 0.0000% 0.0000% 18.6890% 0.0000% 3.0701% 5.7736%
#
#             HPQ     JCI  ...    MSFT     NBL       NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 0.0000% 0.0000% 13.6257% 3.8042% 0.0000% 0.0000%
#
#             TGT     TXT       VZ    ZION
# weights 3.6800% 0.0000% 11.5215% 3.0878%
#
# [1 rows x 24 columns]

# %% [markdown]
# To check if the constraints are verified, I will make a regression among the portfolio returns and risk factors:

# %%
import statsmodels.api as sm

X1 = sm.add_constant(X)
y = np.matrix(returns) * np.matrix(w)
results = sm.OLS(y, X1).fit()
coefs = results.params

print(coefs)
# Out:
# const     0.0235%
# MTUM    -30.0000%
# QUAL      9.5311%
# SIZE     -0.2348%
# USMV    100.9190%
# VLUE     21.5616%
# dtype: float64

# %% [markdown]
# ### 3.3 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w, title='Sharpe FM Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:442: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   wedges, texts = ax.pie(

# %% [markdown]
# ### 3.4 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\cvxpy\problems\problem.py:1060: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
#       APA     BAX     BMY   CMCSA      CNP     CPB      DE     DHR     HPQ  \
# 0 0.0000% 2.0420% 4.5376% 3.7854%  9.3487% 5.3554% 0.0000% 0.6483% 0.0000%
# 1 0.0000% 2.7039% 1.4330% 2.8244% 12.2804% 4.0125% 0.0000% 2.2092% 0.0000%
# 2 0.0000% 2.8294% 0.4820% 2.4774% 13.0713% 3.6002% 0.3210% 2.6525% 0.0000%
# 3 0.0000% 2.8628% 0.0000% 2.1277% 13.7795% 3.2302% 0.6316% 3.0198% 0.0000%
# 4 0.0000% 2.8050% 0.0000% 1.7421% 14.4701% 2.8679% 0.9072% 3.3439% 0.0000%
#
#       JCI  ...    MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 4.7020%  ... 0.0000% 0.0000% 12.8670% 0.0000% 13.7885% 1.3531% 4.2832%
# 1 2.6764%  ... 0.0000% 0.0000% 14.5339% 0.6175%  8.8169% 0.0000% 4.6474%
# 2 1.9944%  ... 0.0000% 0.0000% 15.0007% 0.9187%  7.3421% 0.0000% 4.7156%
# 3 1.3529%  ... 0.0000% 0.0000% 15.4087% 1.1779%  6.0023% 0.0000% 4.7588%
# 4 0.6931%  ... 0.0000% 0.0000% 15.7924% 1.4222%  4.6687% 0.0000% 4.7807%
#
#       TXT       VZ    ZION
# 0 0.0000% 11.4170% 2.2751%
# 1 0.0000% 12.6284% 3.0512%
# 2 0.0000% 12.9145% 3.1167%
# 3 0.0000% 13.1702% 3.1590%
# 4 0.0000% 13.4190% 3.1875%
#
# [5 rows x 24 columns]

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:319: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["{:.4%}".format(x) for x in ax.get_yticks()])
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:320: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["{:.4%}".format(x) for x in ax.get_xticks()])

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\riskfolio\PlotFunctions.py:558: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["{:3.2%}".format(x) for x in ax.get_yticks()])

# %%
display(returns)
# Out:
#                 APA      BAX      BMY    CMCSA      CNP      CPB       DE  \
# 2016-01-05 -0.6216%  0.7015%  0.1909%  0.4771%  0.9283%  0.9924%  0.1760%
# 2016-01-06 -2.8826% -0.6189% -0.9939% -0.8928% -0.5879% -0.3665% -1.6308%
# 2016-01-07 -2.6623% -1.9233% -1.9592% -1.9763% -1.2059% -0.9118% -2.3293%
# 2016-01-08 -1.6392% -1.0494% -0.9502% -1.0563% -1.0629% -0.9912% -1.2714%
# 2016-01-11 -2.1947%  0.3346%  0.0940%  0.1556% -0.0892% -0.0992% -0.6710%
# ...             ...      ...      ...      ...      ...      ...      ...
# 2019-12-20  0.9714%  0.7567%  0.4352%  0.6099%  0.6594%  0.6208%  0.9431%
# 2019-12-23  0.6977% -0.4230% -0.0181% -0.1988% -0.5600% -0.7395%  0.1195%
# 2019-12-24 -0.1975%  0.1506% -0.0503%  0.0391%  0.0930%  0.1012%  0.0556%
# 2019-12-26  0.0838%  0.3568%  0.2717%  0.3344%  0.2787%  0.1975%  0.3099%
# 2019-12-27 -0.7244%  0.2654% -0.0101%  0.1392%  0.3665%  0.3925% -0.1307%
#
#                 DHR      HPQ      JCI  ...     MSFT      NBL       NI  \
# 2016-01-05  0.8162%  0.2262%  0.1024%  ...  0.5345% -0.4322%  1.1712%
# 2016-01-06 -0.3020% -2.2655% -1.2437%  ... -0.9671% -2.7827% -0.0190%
# 2016-01-07 -1.8650% -2.6825% -1.8346%  ... -2.9275% -2.9328% -0.8785%
# 2016-01-08 -0.9815% -1.3391% -1.0316%  ... -1.1005% -1.2201% -0.9977%
# 2016-01-11  0.6154% -0.7521% -0.5531%  ...  0.8840% -0.9994%  0.2115%
# ...             ...      ...      ...  ...      ...      ...      ...
# 2019-12-20  0.7662%  1.0756%  0.7009%  ...  0.8453%  0.8012%  0.5968%
# 2019-12-23 -0.4878%  0.1331%  0.0623%  ... -0.2397%  0.6079% -0.8528%
# 2019-12-24  0.2259% -0.0062%  0.0213%  ...  0.1480% -0.2085%  0.1566%
# 2019-12-26  0.4044%  0.3698%  0.2075%  ...  0.5190%  0.2736%  0.2525%
# 2019-12-27  0.3869% -0.2422% -0.1202%  ...  0.1561% -0.6260%  0.5586%
#
#                PCAR      PSA      SEE      TGT      TXT       VZ     ZION
# 2016-01-05 -0.1142%  0.8781%  0.3503%  0.1709% -0.2179%  0.9760% -0.3588%
# 2016-01-06 -2.1627% -0.0372% -1.3296% -1.3348% -1.8858% -0.9189% -2.5078%
# 2016-01-07 -2.6700% -1.0104% -1.9327% -1.5868% -2.5818% -1.1148% -2.2576%
# 2016-01-08 -1.3251% -0.9137% -1.2707% -0.7749% -1.3179% -0.9447% -1.1159%
# 2016-01-11 -0.7606%  0.3162% -0.5902% -0.4203% -0.8322% -0.1965% -1.4506%
# ...             ...      ...      ...      ...      ...      ...      ...
# 2019-12-20  0.7452%  0.4033%  0.7251%  0.6842%  0.7578%  0.7437%  0.9387%
# 2019-12-23  0.4848% -0.6862% -0.1714%  0.1147%  0.3195% -0.5775%  0.6393%
# 2019-12-24 -0.1183%  0.0728% -0.0242%  0.0305% -0.0877%  0.0779% -0.0758%
# 2019-12-26  0.3526%  0.2093%  0.2125%  0.2577%  0.2180%  0.2815%  0.2243%
# 2019-12-27 -0.3002%  0.4283% -0.0298% -0.1121% -0.3575%  0.2902% -0.5422%
#
# [1003 rows x 24 columns]

# %% [markdown]
# ## 4. Estimating Portfolios Using Risk Factors with Other Risk Measures
#
# In this part I will calculate optimal portfolios for several risk measures. I will find the portfolios that maximize the risk adjusted return for all available risk measures.
#
# ### 4.1 Calculate Optimal Portfolios for Several Risk Measures.
#
# I will mantain the constraints on risk factors.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

# port.reset_linear_constraints() # To reset linear constraints (factor constraints)

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'WR', 'MDD', 'ADD', 'CDaR']

w_s = pd.DataFrame([])

# When we use hist = True the risk measures all calculated
# using historical returns, while when hist = False the
# risk measures are calculated using the expected returns 
#  based on risk factor model: R = a + B * F

hist = False

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms
# Out:
# C:\Users\joe\Anaconda3\envs\stochastic-finance\lib\site-packages\cvxpy\problems\problem.py:1060: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
# #T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow0_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow1_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow2_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow3_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow5_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow6_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow8_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col0,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col2,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col3,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col4,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col5,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col6,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col7,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col8,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow9_col9,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow10_col1,#T_82b23401_3b04_11eb_9f2b_f8b46ac0975drow10_col2,#T_82b23401_3b04_11eb_9f2b_f8 ...

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>

# %%
w_s = pd.DataFrame([])

# When we use hist = True the risk measures all calculated
# using historical returns, while when hist = False the
# risk measures are calculated using the expected returns 
#  based on risk factor model: R = a + B * F

hist = True

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
# #T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col8,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow0_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow1_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col8,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow2_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col8,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow3_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col8,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow5_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow6_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow6_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow6_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow6_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow6_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col8,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow8_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col3,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col4,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col8,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow9_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow10_col5,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow10_col6,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow10_col7,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow10_col9,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow11_col0,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow11_col1,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow11_col2,#T_91edd61c_3b04_11eb_8075_f8b46ac0975drow11_col3,#T_91edd61c_3b04_11eb_8 ...

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
